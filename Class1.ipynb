# %% [markdown]
# ---
#
# ### **What is XR?**
#
# - **Extended Reality (XR)**: A term that encompasses a spectrum of real and virtual environments and human-computer interactions.
# - **Always Evolving**: The field of XR is rapidly changing, incorporating new technologies and approaches.
# - **Definition 1**: The use of modern technology for innovative tools and problem-solving.
# - **Definition 2**: An umbrella term for all combined real and virtual environments, as well as man-machine interactions.
#
# ---
#
# ### **Class Outline**
#
# | **Topic**                                | **Duration**       |
# |------------------------------------------|--------------------|
# | **Introduction to XR**                   | Week 1             |
# | **Virtual Reality (VR), Augmented Reality (AR), Mixed Reality (MR)** | Weeks 2-3          |
# | **Motion Capture (MoCap) / Full Body Tracking (FBT)** | Weeks 4-5          |
# | **Computer-Aided Design (CAD)**          | Weeks 6-7          |
# | **Prosthetics**                    | Weeks 8-9          |
# | **Human-Controlled Robots (HCR)**        | Weeks 10-11        |
# | **Brain-Computer Interface (BCI)**       | Weeks 12-13        |
# | **Artificial Intelligence (AI) in XR**  | Weeks 14-15        |
# | **Final Project Presentation**           | Week 16            |
#
# ---
#
# ### **Syllabus**
#
# - The syllabus is available on **Canvas**. Please refer to it for detailed course requirements and guidelines.
#
# ---
#
# ### **Jupyter Notebook Setup**
#
# 1. **Install Anaconda**:
#    - Download and install from [here](https://www.anaconda.com/download).
#
# 2. **Download Assignment Template**:
#    - Obtain the template for assignments from **Canvas**.
#
# 3. **Launch Anaconda Navigator**:
#    - Open Anaconda Navigator and start Jupyter Notebook.
#
# 4. **Run Jupyter Notebook**:
#    - Launch the Jupyter Notebook environment for coding and assignments.
#
# ---
#
# ### **Assignment**
#
# - **Discussion Board Prompt**:
#   *"Name one technology encompassed by XR that is not VR, AR, or MR."*
#
# - **Instructions**:
#   Respond to the prompt and reply to at least one classmate’s post.
#
# - **Due**:
#   Before the next class.
#
# ---
