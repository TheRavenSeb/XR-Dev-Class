# %% [markdown]
# # Class 2
# ---
# ## VR/AR/MR
#
# ### Virtual Reality (VR)
# Virtual Reality (VR) is a simulated experience that can be similar to or completely different from the real world.
#
#
#
# ### Augmented Reality (AR)
# Augmented Reality (AR) is an interactive experience of a real-world environment where the objects that reside in the real world are enhanced by computer-generated perceptual information.
#
#
# ### Mixed Reality (MR)
# Mixed Reality (MR) is the merging of real and virtual worlds to produce new environments and visualizations where physical and digital objects co-exist and interact in real time.
#
# ---
#
# ## Technologies
#
# - Virtual Reality (VR)
#   - Hardware
#     - Meta Quest ![image](<img src = "https://m.media-amazon.com/images/I/71j-U6Z2MkL.jpg" width="50px" height="50px"/>)
#
#     - HTC Vive <!--( talk about base staions and controllers)-->
#     - PlayStation VR
#     - Samsung Gear VR
#     - Google Cardboard <!-- one of the first vr headsets for the mass market -->
#
#   - Software
#     - Unity <!-- game engine>
#     - Unreal Engine <!-- talk about game engine show buring car video, realistic renders video: https://www.youtube.com/watch?v=CoUADpVL9gY>
#     - Blender <!-- sculpting -->
#     - SketchUp <!-- CAD softwere -->
#
#
# - Augmented Reality (AR) <!-- overlay rather then screen -- >
#   - Hardware
#     - Google Glass
#     - Vuzix Blade
#     - Epson Moverio BT-300
#     - Magic Leap Two
#     - Focals by North <!-- bought out by google -->
#
#   - Software
#     - Unity
#     - Unreal Engine
#     - Vuforia
#     - ARToolKit <!-- Made specifily for AR divices -- >
#     - Kudan
#
# - Mixed Reality (MR)
#   - Hardware <!-- mainly an execative divices https://youtu.be/8DWrZroUOxI?si=YLu2Ez1NXNjiNBkW>
#     - Microsoft HoloLens <!-- hand tracking discontiuned dec 10 2024 VERY CURRENT changing quickly>
#     - Meta 2 <!-- IR passthrough  hand/object tracking>
#     - Lynx R-1
#     - apple vision pro <!-- apple glasses>
#     - ThirdEye Gen X1
#
#   - Software
#     - Unity
#     - Unreal Engine
#     - Vuforia
#     - ARToolKit
#     - Kudan
#
#
# ---
#
# ## Asignment
# <!-- make an iframe for the video https://www.youtube.com/watch?v=y8RXyABMEzQ-->
# Watch the following video: [![VR/AR/MR](https://img.youtube.com/vi/y8RXyABMEzQ/0.jpg)](https://www.youtube.com/watch?v=y8RXyABMEzQ)
#
# Answer the following questions about VR/AR/MR:
#
#
#
#
#
# ### Questions
#
#
#
#
#
#
# Create something in [Unity] anyting you want, and attach a screenshot to a markdown table.
